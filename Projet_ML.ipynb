# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import seaborn as sns

from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import seaborn as sns
sns.set()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(path+'/features_3_sec.csv')
df.head()
# Out:
#             filename  length  chroma_stft_mean  ...  mfcc20_mean  mfcc20_var  label
# 0  blues.00000.0.wav   66149          0.335406  ...    -0.243027   43.771767  blues
# 1  blues.00000.1.wav   66149          0.343065  ...     5.784063   59.943081  blues
# 2  blues.00000.2.wav   66149          0.346815  ...     2.517375   33.105122  blues
# 3  blues.00000.3.wav   66149          0.363639  ...     3.630866   32.023678  blues
# 4  blues.00000.4.wav   66149          0.335579  ...     0.536961   29.146694  blues
#
# [5 rows x 60 columns]

# %%
df.shape
# Out:
# (9990, 60)

# %%
df['label'].value_counts()
# Out:
# metal        1000
# blues        1000
# reggae       1000
# pop          1000
# jazz         1000
# disco         999
# classical     998
# rock          998
# hiphop        998
# country       997
# Name: label, dtype: int64

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
df['labelCode'] = label_encoder.fit_transform(df['label'])
df.head()
# Out:
#             filename  length  chroma_stft_mean  ...  mfcc20_var  label  labelCode
# 0  blues.00000.0.wav   66149          0.335406  ...   43.771767  blues          0
# 1  blues.00000.1.wav   66149          0.343065  ...   59.943081  blues          0
# 2  blues.00000.2.wav   66149          0.346815  ...   33.105122  blues          0
# 3  blues.00000.3.wav   66149          0.363639  ...   32.023678  blues          0
# 4  blues.00000.4.wav   66149          0.335579  ...   29.146694  blues          0
#
# [5 rows x 61 columns]

# %%
lables = df.iloc[:,-2:].drop_duplicates().style.hide_index()
df = df.drop(['label','filename'],axis=1)

# %%
lables
# Out:
# <style  type="text/css" >
# </style><table id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >label</th>        <th class="col_heading level0 col1" >labelCode</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row0_col0" class="data row0 col0" >blues</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row1_col0" class="data row1 col0" >classical</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row1_col1" class="data row1 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row2_col0" class="data row2 col0" >country</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row2_col1" class="data row2 col1" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row3_col0" class="data row3 col0" >disco</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row3_col1" class="data row3 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row4_col0" class="data row4 col0" >hiphop</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row5_col0" class="data row5 col0" >jazz</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row5_col1" class="data row5 col1" >5</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row6_col0" class="data row6 col0" >metal</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row7_col0" class="data row7 col0" >pop</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row7_col1" class="data row7 col1" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row8_col0" class="data row8 col0" >reggae</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row8_col1" class="data row8 col1" >8</td>
#             </tr>
#             <tr>
#                                 <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row9_col0" class="data row9 col0" >rock</td>
#                         <td id="T_7a4cab1a_da56_11eb_8e40_0242ac1c0002row9_col1" class="data row9 col1" >9</td>
#             </tr>
#     </tbody></table>

# %%
df.rename(columns={'labelCode': 'label'}, inplace=True)

# %%
from random import sample
df = df.sample(frac=1)

# %%
df
# Out:
#       length  chroma_stft_mean  chroma_stft_var  ...  mfcc20_mean  mfcc20_var  label
# 5611   66149          0.322053         0.089146  ...    -3.545785   46.914303      5
# 674    66149          0.327551         0.081509  ...     0.712430   68.903839      0
# 1201   66149          0.355403         0.089386  ...    -4.662103   68.919098      1
# 9058   66149          0.326408         0.082417  ...    -1.718348   23.797945      9
# 7614   66149          0.267455         0.093911  ...    -0.017204  156.340317      7
# ...      ...               ...              ...  ...          ...         ...    ...
# 8700   66149          0.395371         0.090187  ...    -3.571296   64.634331      8
# 8768   66149          0.402109         0.087911  ...    -1.655752   23.783375      8
# 2982   66149          0.286681         0.089819  ...    -2.712241   34.791752      2
# 8541   66149          0.424903         0.098549  ...    -4.290097   71.050308      8
# 8629   66149          0.330384         0.094142  ...     0.983567   43.546906      8
#
# [9990 rows x 59 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9990 entries, 5611 to 8629
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   length                   9990 non-null   int64
#  1   chroma_stft_mean         9990 non-null   float64
#  2   chroma_stft_var          9990 non-null   float64
#  3   rms_mean                 9990 non-null   float64
#  4   rms_var                  9990 non-null   float64
#  5   spectral_centroid_mean   9990 non-null   float64
#  6   spectral_centroid_var    9990 non-null   float64
#  7   spectral_bandwidth_mean  9990 non-null   float64
#  8   spectral_bandwidth_var   9990 non-null   float64
#  9   rolloff_mean             9990 non-null   float64
#  10  rolloff_var              9990 non-null   float64
#  11  zero_crossing_rate_mean  9990 non-null   float64
#  12  zero_crossing_rate_var   9990 non-null   float64
#  13  harmony_mean             9990 non-null   float64
#  14  harmony_var              9990 non-null   float64
#  15  perceptr_mean            9990 non-null   float64
#  16  perceptr_var             9990 non-null   float64
#  17  tempo                    9990 non-null   float64
#  18  mfcc1_mean               9990 non-null   float64
#  19  mfcc1_var                9990 non-null   float64
#  20  mfcc2_mean               9990 non-null   float64
#  21  mfcc2_var                9990 non-null   float64
#  22  mfcc3_mean               9990 non-null   float64
#  23  mfcc3_var                9990 non-null   float64
#  24  mfcc4_mean               9990 non-null   float64
#  25  mfcc4_var                9990 non-null   float64
#  26  mfcc5_mean               9990 non-null   float64
#  27  mfcc5_var                9990 non-null   float64
#  28  mfcc6_mean               9990 non-null   float64
#  29  mfcc6_var                9990 non-null   float64
#  30  mfcc7_mean               9990 non-null   float64
#  31  mfcc7_var                9990 non-null   float64
#  32  mfcc8_mean               9990 non-null   float64
#  33  mfcc8_var                9990 non-null   float64
#  34  mfcc9_mean               9990 non-null   float64
#  35  mfcc9_var                9990 non-null   float64
#  36  mfcc10_mean              9990 non-null   float64
#  37  mfcc10_var               9990 non-null   float64
#  38  mfcc11_mean              9990 non-null   float64
#  39  mfcc11_var               9990 non-null   float64
#  40  mfcc12_mean              9990 non-null   float64
#  41  mfcc12_var               9990 non-null   float64
#  42  mfcc13_mean              9990 non-null   float64
#  43  mfcc13_var               9990 non-null   float64
#  44  mfcc14_mean              9990 non-null   float64
#  45  mfcc14_var               9990 non-null   float64
#  46  mfcc15_mean              9990 non-null   float64
#  47  mfcc15_var               9990 non-null   float64
#  48  mfcc16_mean              9990 non-null   float64
#  49  mfcc16_var               9990 non-null   float64
#  50  mfcc17_mean              9990 non-null   float64
#  51  mfcc17_var               9990 non-null   float64
#  52  mfcc18_mean              9990 non-null   float64
#  53  mfcc18_var               9990 non-null   float64
#  54  mfcc19_mean              9990 non-null   float64
#  55  mfcc19_var               9990 non-null   float64
#  56  mfcc20_mean              9990 non-null   float64
#  57  mfcc20_var               9990 non-null   float64
#  58  label                    9990 non-null   int64
# dtypes: float64(57), int64(2)
# memory usage: 4.6 MB

# %% [markdown]
# # **normalized DataSet**

# %%
from sklearn import preprocessing

y = df.iloc[:,58:]
X = df.iloc[:,1:58]
scaler = preprocessing.MinMaxScaler()
normalizedDataSet = scaler.fit_transform(df)
X_normalized = pd.DataFrame(normalizedDataSet,columns=df.columns)

# %%
X_normalized.head()
# Out:
#    length  chroma_stft_mean  chroma_stft_var  ...  mfcc20_mean  mfcc20_var     label
# 0     0.0          0.334611         0.698744  ...     0.459465    0.051233  0.555556
# 1     0.0          0.343171         0.626444  ...     0.520425    0.075393  0.000000
# 2     0.0          0.386528         0.701019  ...     0.443484    0.075409  0.111111
# 3     0.0          0.341391         0.635032  ...     0.485626    0.025836  1.000000
# 4     0.0          0.249618         0.743863  ...     0.509979    0.171457  0.777778
#
# [5 rows x 59 columns]

# %% [markdown]
# ## **Split DATA**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.45, random_state=111)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5494, 59), (4496, 59), (5494, 1), (4496, 1))

# %% [markdown]
# # **Random Forest**

# %%
randomforest = RandomForestClassifier(n_estimators=1000, max_depth=None, random_state=21)
randomforest.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=21, verbose=0,
#                        warm_start=False)

# %%
preds = randomforest.predict(X_test)
c_matrix = confusion_matrix(y_test, preds)
print('Accuracy:', round(accuracy_score(y_test, preds), 5), '\n')
sns.heatmap(c_matrix, annot=True,fmt='1', cmap='Blues')
# Out:
# Accuracy: 0.98754

# %% [markdown]
# # **Neural Network**

# %%
nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(1000, 10), random_state=1)
nn.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(1000, 10), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=1, shuffle=True, solver='lbfgs',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
preds = nn.predict(X_test)
c_matrix = confusion_matrix(y_test, preds)
print('Accuracy:', round(accuracy_score(y_test, preds), 5), '\n')
sns.heatmap(c_matrix, annot=True,fmt='1', cmap='Blues')
# Out:
# Accuracy: 0.99867

# %% [markdown]
# # **Naive Bayes**

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py:206: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
preds = nb.predict(X_test)
c_matrix = confusion_matrix(y_test, preds)
print('Accuracy:', round(accuracy_score(y_test, preds), 5), '\n')
sns.heatmap(c_matrix, annot=True,fmt='1', cmap='Blues')
# Out:
# Accuracy: 1.0

# %% [markdown]
# # **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=19)
knn.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#                      weights='uniform')

# %%
preds = knn.predict(X_test)
c_matrix = confusion_matrix(y_test, preds)
print('Accuracy:', round(accuracy_score(y_test, preds), 5), '\n')
sns.heatmap(c_matrix, annot=True,fmt='1', cmap='Blues')
# Out:
# Accuracy: 0.92616

# %% [markdown]
# # **Decission trees**

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
preds = tree.predict(X_test)
c_matrix = confusion_matrix(y_test, preds)
print('Accuracy:', round(accuracy_score(y_test, preds), 5), '\n')
sns.heatmap(c_matrix, annot=True,fmt='1', cmap='Blues')
# Out:
# Accuracy: 1.0

# %% [markdown]
# # **Support Vector Machine**

# %%
svm = SVC(decision_function_shape="ovo")
svm.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovo', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
preds = svm.predict(X_test)
c_matrix = confusion_matrix(y_test, preds)
print('Accuracy:', round(accuracy_score(y_test, preds), 5), '\n')
sns.heatmap(c_matrix, annot=True,fmt='1', cmap='Blues')
# Out:
# Accuracy: 0.98643

# %% [markdown]
# # **Logistic Regression**

# %%
lg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
lg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
preds = lg.predict(X_test)
c_matrix = confusion_matrix(y_test, preds)
print('Accuracy:', round(accuracy_score(y_test, preds), 5), '\n')
sns.heatmap(c_matrix, annot=True,fmt='1', cmap='Blues')
# Out:
# Accuracy: 0.90903

# %% [markdown]
# ## **Data Without Preprocessing**

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.45, random_state=111)
X_train1.shape, X_test1.shape, y_train1.shape, y_test1.shape
# Out:
# ((5494, 57), (4496, 57), (5494, 1), (4496, 1))

# %%
randomforest1 = RandomForestClassifier(n_estimators=1000, max_depth=None, random_state=21)
randomforest1.fit(X_train1, y_train1)
nn1 = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(1000, 10), random_state=1)
nn1.fit(X_train1, y_train1)
nb1 = GaussianNB()
nb1.fit(X_train1, y_train1)
knn1 = KNeighborsClassifier(n_neighbors=19)
knn1.fit(X_train1, y_train1)
tree1 = DecisionTreeClassifier()
tree1.fit(X_train1, y_train1)
svm1 = SVC(decision_function_shape="ovo")
svm1.fit(X_train1, y_train1)
lg1 = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
lg1.fit(X_train1, y_train1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py:206: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Models= {"modem" : ["KNN","Logistic Regression","Decission trees","Naive Bayes","Support Vector Machine","Random Forest","Neural Nets"],
         "With data processing":[knn,lg,tree,nb,svm,randomforest,nn],
         "Without data processing":[knn1,lg1,tree1,nb1,svm1,randomforest1,nn1]}

# %%
def accuracy(model,X_test,y_test):
  preds = model.predict(X_test)
  return round(accuracy_score(y_test, preds), 5)

# %%
m = Models
for i in range(len(Models["With data processing"])):
  m["With data processing"][i]=accuracy(Models["With data processing"][i],X_test,y_test)
  m["Without data processing"][i]=accuracy(Models["Without data processing"][i],X_test1,y_test1)

# %%
pd.DataFrame.from_dict(m)
# Out:
#                     modem  With data processing  Without data processing
# 0                     KNN               0.92616                  0.28092
# 1     Logistic Regression               0.90903                  0.21552
# 2         Decission trees               1.00000                  0.60921
# 3             Naive Bayes               1.00000                  0.42438
# 4  Support Vector Machine               0.98643                  0.28403
# 5           Random Forest               0.98754                  0.85142
# 6             Neural Nets               0.99867                  0.10231
